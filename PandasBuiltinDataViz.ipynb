# %% [markdown]
# <a href="https://colab.research.google.com/github/sidchaubey/Python_Revision/blob/master/PandasBuiltinDataViz.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
df = sns.load_dataset("iris")
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.set_style("darkgrid")

df["sepal_length"].hist()

# %%
df["sepal_length"].hist(bins=30)

# %%
df["sepal_length"].plot(kind="hist", bins=10)

# %%
df["sepal_length"].plot.hist()

# %%
df.plot.area()

# %%
df.plot.area(alpha=0.4)

# %%
df[:10].plot.bar()

# %%
df[:10].plot.bar(stacked=True)

# %%
df["petal_length"].plot.hist(bins=50)

# %%
df.plot.line()

# %%
# df.plot.line(x=df.index, y="sepal_length")# for timeseries

# %%
df.plot.scatter(x="petal_length", y="sepal_length")

# %%
df.plot.scatter(x="petal_length", y="sepal_length", c="C")
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/plotting/_matplotlib/core.py:1016: MatplotlibDeprecationWarning: Support for uppercase single-letter colors is deprecated since Matplotlib 3.1 and will be removed in 3.3; please use lowercase instead.
#   **self.kwds,

# %%
df.plot.scatter(x="petal_length", y="sepal_length", c="C", cmap="coolwarm")

# %%
df.plot.scatter(x="petal_length", y="sepal_length", c="sepal_width")

# %%
df.plot.box()

# %%
df1 = pd.DataFrame(np.random.rand(1000, 2), columns=["a", "b"])
df1.head()
# Out:
#           a         b
# 0  0.864918  0.858125
# 1  0.459030  0.071909
# 2  0.652748  0.224069
# 3  0.982362  0.822648
# 4  0.526530  0.950517

# %%
df1.plot.hexbin(x="a", y="b")

# %%
df1.plot.hexbin(x="a", y="b", gridsize=25)

# %%
df1.plot.hexbin(x="a", y="b", cmap="coolwarm")

# %%
df2 = pd.DataFrame(np.random.randn(1000, 2), columns=["a", "b"])
df2.head()
# Out:
#           a         b
# 0  0.502098 -1.208767
# 1 -0.821956 -1.179765
# 2  1.211332  0.194279
# 3 -0.868834 -0.259701
# 4  0.166273 -0.260235

# %%
df1.plot.hexbin(x="a", y="b", gridsize=25)

# %%
df2.plot.hexbin(x="a", y="b", cmap="coolwarm")

# %%
df2.plot.hexbin(x="a", y="b", gridsize=25, cmap="coolwarm")

# %%
df2.plot.density()

# %%
df1.plot.density()
